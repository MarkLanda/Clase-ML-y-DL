# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkLanda/Clase-ML-y-DL/blob/main/Rutax/borrador_clase1_dd2032.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
0+21
# Out:
# 21

# %%
1-1
# Out:
# 0

# %%
# Out:
#   File "<ipython-input-9-c4ae3b17f9b7>", line 1
#     Este es un título
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 2018
# ####![4EF6CFD6-8682-41C7-AC71-DEC9EB2BD94A.JPG](data:image/jpeg;base64,...) este es un titulo
